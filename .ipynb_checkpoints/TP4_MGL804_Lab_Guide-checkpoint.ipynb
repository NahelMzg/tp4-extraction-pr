# %% [markdown]
# #  TP 4 : Étude empirique : les pratiques de refactoring avec les agents IA
# ## MGL804 – Réalisation et maintenance des logiciels
#
# **Objectifs :**
# 1. **Partie 1** — Quantifier la prévalence des suggestions de refactoring dans les commentaires de révision humains sur des PRs agentiques.
# 2. **Partie 2** — Vérifier avec RefactoringMiner si les agents appliquent ces suggestions.
#
# **Jeu de données :** [AIDev](https://huggingface.co/datasets/hao-li/AIDev) (sous-ensemble AIDev-pop)
#
# > ⚠️ Ce notebook est un **guide de laboratoire**. Il fournit la structure, des indices et des points de départ — **c'est à vous d'écrire le code**. Les cellules marquées `# TODO` ou `# VOTRE CODE ICI` sont à compléter.\n",
#
# > 🚨 **Avertissement important :** Les indices fournis dans ce notebook (noms de colonnes, noms de variables, exemples de jointures) sont indicatifs et peuvent ne pas correspondre exactement à la structure réelle des données. **Vous devez explorer les tables vous-même, vérifier les noms de colonnes réels avec `.columns` ou `.head()`, et adapter votre code en conséquence — ne copiez pas les indices sans les valider au préalable.**

# %% [markdown]
# ---
# ## 0. Installation et configuration
#
# Exécutez cette cellule une seule fois pour installer les dépendances.

# %%
# Décommentez si nécessaire :
# !pip install pandas pyarrow matplotlib seaborn scipy tqdm datasets nbformat python-dotenv
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (3.0.2)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.13/site-packages (23.0.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.13/site-packages (1.17.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (4.67.3)
# Requirement already satisfied: datasets in ./.venv/lib/python3.13/site-packages (4.8.4)
# Requirement already satisfied: nbformat in ./.venv/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from datasets) (3.28.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in ./.venv/lib/python3.13/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.13/site-packages (from datasets) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in ./.venv/lib/python3.13/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in ./.venv/lib/python3.13/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in ./.venv/lib/python3.13/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in ./.venv/lib/python3.13/site-packages (from datasets) (1.11.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.13/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.13/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in ./.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.3)
# Requirement already satisfied: typer in ./.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.13/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.13/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.13/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./.venv/lib/python3.13/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.6)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: click>=8.2.1 in ./.venv/lib/python3.13/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.13/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in ./.venv/lib/python3.13/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.13/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### 0.1 Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json
import subprocess
import os
from dotenv import load_dotenv
from tqdm.auto import tqdm
from scipy import stats

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 120)
sns.set_theme(style="whitegrid")

print("Imports réussis")
# Out:
# Imports réussis

# %% [markdown]
# ### 0.2 Configuration de Java et RefactoringMiner
#
# RefactoringMiner 3.x requiert **Java 17+**. Si votre serveur a une version plus ancienne, installez-la via conda.
#
# > **Indice :** Vérifiez votre version Java avec `!java -version`. Si c'est Java 8 ou 11, vous devez installer Java 17.

# %%
# Vérifiez votre version Java actuelle
# !java -version
# Out:
# openjdk version "21.0.10" 2026-01-20
# OpenJDK Runtime Environment Homebrew (build 21.0.10)
# OpenJDK 64-Bit Server VM Homebrew (build 21.0.10, mixed mode, sharing)

# %%
# Si Java < 17, décommentez et exécutez :
# !conda install -c conda-forge openjdk=17 -y

# Puis configurez le PATH :
# import os
# conda_base = os.popen('conda info --base').read().strip()
# java17_home = f"{conda_base}/lib/jvm"
# os.environ['JAVA_HOME'] = java17_home
# os.environ['PATH'] = f"{java17_home}/bin:{os.environ['PATH']}"
# !java -version

# %%
# Token GitHub pour l'API (nécessaire pour le mode -gc / -gp de RefactoringMiner)
# Le token est chargé depuis le fichier .env (jamais commité dans git)
# Créez un .env à la racine du projet avec : GITHUB_OAUTH=ghp_...

load_dotenv()

if not os.environ.get('GITHUB_OAUTH'):
    raise ValueError("GITHUB_OAUTH manquant — ajoutez-le dans votre fichier .env")

# ─── Configuration RefactoringMiner ───────────────────────────────────────────
import subprocess
import os
RMINER_LIB = os.path.expanduser("~/RefactoringMiner/build/distributions/RefactoringMiner-3.1.3/lib")
RMINER_CMD = ["java", "-cp", RMINER_LIB + "/*", "org.refactoringminer.RefactoringMiner"]

result = subprocess.run(RMINER_CMD + ["-h"], capture_output=True, text=True, timeout=30)
if "Show options" in result.stdout or "RefactoringMiner" in result.stdout:
    print("✅ RefactoringMiner 3.1.3 opérationnel")
else:
    print("❌ Problème RefactoringMiner — stdout:", result.stdout[:200])
    print("   stderr:", result.stderr[:200])
# Out:
# ✅ RefactoringMiner 3.1.3 opérationnel

# %% [markdown]
# ---
# ## 1. Chargement des données AIDev
#
# Nous chargeons les tables Parquet directement depuis Hugging Face.
#
# > **Indice :** Après le premier chargement, sauvegardez localement avec `df.to_parquet("local_file.parquet")` pour accélérer les exécutions suivantes.

# %%
print("Chargement des pull requests...")
df_prs = pd.read_parquet("hf://datasets/hao-li/AIDev/pull_request.parquet")

print("Chargement des commentaires de révision (v2)...")
df_review_comments = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_review_comments_v2.parquet")

print("Chargement des commits par PR...")
df_commits = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commits.parquet")

print("Chargement des détails de commits...")
df_commit_details = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commit_details.parquet")

print("Chargement de la timeline...")
df_timeline = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_timeline.parquet")

print("Chargement des reviews...")
df_reviews = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_reviews.parquet")

print("Chargement des dépôts...")
df_repos = pd.read_parquet("hf://datasets/hao-li/AIDev/repository.parquet")

print("\n✅ Toutes les tables sont chargées.")
# Out:
# Chargement des pull requests...
# Chargement des commentaires de révision (v2)...
# Chargement des commits par PR...
# Chargement des détails de commits...
# Chargement de la timeline...
# Chargement des reviews...
# Chargement des dépôts...
#
# ✅ Toutes les tables sont chargées.

# %% [markdown]
# ### 1.1 Exploration rapide des données
#
# Prenez le temps d'explorer la structure de chaque table avant de commencer l'analyse.
#
# > **Indice :** Pour chaque table, examinez les colonnes, le nombre de lignes, et quelques lignes avec `.head()`. Identifiez les clés de jointure potentielles (`id`, `pr_id`, `repo_id`, etc.).

# %%
# Aperçu des tables et de leurs colonnes
tables = {
    "pull_request": df_prs,
    "pr_review_comments_v2": df_review_comments,
    "pr_commits": df_commits,
    "pr_commit_details": df_commit_details,
    "pr_timeline": df_timeline,
    "pr_reviews": df_reviews,
    "repository": df_repos,
}

for name, df in tables.items():
    print(f"\n{'='*60}")
    print(f"{name} — {len(df):,} lignes, {len(df.columns)} colonnes")
    print(f"   Colonnes : {list(df.columns)}")

# %%
# TODO : Explorez les tables individuellement
# Essayez : df_prs.head(3), df_review_comments.head(3), df_repos.head(3)
# Repérez les colonnes clés pour les jointures à venir.

# VOTRE CODE ICI

# %% [markdown]
# ---
# ## Partie 1 : Prévalence des suggestions de refactoring (13 pts)

# %% [markdown]
# ### Étape 1.1 — Filtrer les PRs agentiques
#
# Les 5 agents connus dans AIDev sont : **Codex, Devin, Copilot, Cursor, Claude Code**.
#
# > **Indice :** Cherchez une colonne dans `df_prs` qui identifie l'agent (ex. `'agent'`). Affichez ses valeurs uniques avec `.unique()` pour connaître les noms exacts, puis filtrez avec `.isin()`.

# %%
# TODO : Identifiez la colonne qui indique l'agent et affichez ses valeurs uniques

# VOTRE CODE ICI

# %%
# TODO : Filtrez les PRs agentiques en utilisant les noms exacts trouvés ci-dessus
#
# INDICE :
#   AGENTS = ['OpenAI_Codex', 'Copilot', 'Devin', 'Cursor', 'Claude_Code']  # vérifiez les noms exacts
#   df_agentic = df_prs[df_prs['agent'].isin(AGENTS)]
#
# Affichez le nombre de PRs par agent avec .value_counts()

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.2 — Joindre avec les commentaires de révision
#
# Fusionnez les PRs agentiques avec les commentaires inline. **Gardez tous les commentaires** (humains et bots), puis analysez la distribution des auteurs (humain vs IA/bot).
#
# > **Indice :** Il n'y a pas de clé directe entre `df_review_comments` et `df_prs`. Vous devez passer par `df_reviews` comme table intermédiaire :
# > 1. `df_review_comments` → `df_reviews` (via `pull_request_review_id` ↔ `id`)
# > 2. Résultat → `df_prs` (via `pr_id` ↔ `id`)
# >
# > Utilisez `.merge()` avec le paramètre `suffixes` pour éviter les conflits de noms de colonnes.
# >
# > Après la jointure, explorez la colonne auteur pour distinguer les commentaires humains des commentaires bot/IA et affichez la distribution (ex. `.value_counts()`).

# %%
# TODO : Trouvez les colonnes communes entre les tables
print("Colonnes PR      :", sorted(df_prs.columns))
print("Colonnes Reviews :", sorted(df_reviews.columns))
print("Colonnes Comments:", sorted(df_review_comments.columns))

# %%
# TODO : Effectuez la jointure en deux étapes
#
# INDICE :
#   Étape A : review_comments + reviews
#     df_merged = df_review_comments.merge(df_reviews,
#         left_on='pull_request_review_id', right_on='id',
#         how='left', suffixes=('_review_comment', '_review'))
#
#   Étape B : résultat + pull_request
#     df_comments = df_merged.merge(df_prs,
#         left_on='pr_id', right_on='id',
#         how='left', suffixes=('_comment', '_pr'))
#
# Vérifiez avec df_comments.shape et df_comments.head(3)

# VOTRE CODE ICI

# %%
# TODO : Analysez la distribution des commentaires humains vs bots/IA
#
# INDICES :
#   1. Cherchez la colonne auteur : [c for c in df_comments.columns if 'user' in c.lower() or 'author' in c.lower()]
#   2. Identifiez les bots (souvent le nom contient '[bot]' ou 'github-actions')
#   3. Affichez la distribution : combien de commentaires humains vs bots ?
#   4. Visualisez avec un barplot ou un camembert
#
# NOTE : Gardez TOUS les commentaires dans df_comments pour la suite de l'analyse.

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.3 — Identifier les commentaires de refactoring (mots-clés)
#
# Appliquez le dictionnaire de mots-clés fourni dans l'énoncé.
#
# > **Indice :** Combinez les regex en un seul pattern avec `'|'.join(patterns)`, puis appliquez `.str.contains()` sur la colonne body des commentaires. Attention au paramètre `na=False` pour gérer les valeurs manquantes.

# %%
import re

# Patterns de détection de refactoring (fournis dans l'énoncé)
KEYWORD_PATTERNS = {
    "Add*"                         : r"\badd\w*",
    "Chang*"                       : r"\bchang\w*",
    "Chang* the name"              : r"\bchang\w*\s+the\s+name",
    "Cleanup"                      : r"\bcleanup\b",
    "Clean* up"                    : r"\bclean\w*\s+up",
    "Code clarity"                 : r"\bcode\s+clarity",
    "Code clean*"                  : r"\bcode\s+clean\w*",
    "Code organization"            : r"\bcode\s+organization",
    "Code review"                  : r"\bcode\s+review",
    "Clean code"                   : r"\bclean\s+code",
    "Creat*"                       : r"\bcreat\w*",
    "Customiz*"                    : r"\bcustomiz\w*",
    "Easier to maintain"           : r"\beasier\s+to\s+maintain",
    "Encapsulat*"                  : r"\bencapsulat\w*",
    "Enhanc*"                      : r"\benhanc\w*",
    "Extend*"                      : r"\bextend\w*",
    "Extract*"                     : r"\bextract\w*",
    "Fix*"                         : r"\bfix\w*",
    "Inlin*"                       : r"\binlin\w*",
    "Improv*"                      : r"\bimprov\w*",
    "Improv* code quality"         : r"\bimprov\w*\s+code\s+quality",
    "Introduc*"                    : r"\bintroduc\w*",
    "Merg*"                        : r"\bmerg\w*",
    "Modif*"                       : r"\bmodif\w*",
    "Modulariz*"                   : r"\bmodulariz\w*",
    "Migrat*"                      : r"\bmigrat\w*",
    "Mov*"                         : r"\bmov\w*",
    "Organiz*"                     : r"\borganiz\w*",
    "Polish*"                      : r"\bpolish\w*",
    "Reduc*"                       : r"\breduc\w*",
    "Refactor*"                    : r"\brefactor\w*",
    "Refin*"                       : r"\brefin\w*",
    "Remov*"                       : r"\bremov\w*",
    "Remov* redundant code"        : r"\bremov\w*\s+redundant\s+code",
    "Renam*"                       : r"\brenam\w*",
    "Remov* unused dependencies"   : r"\bremov\w*\s+unused\s+dependenc\w*",
    "Reorganiz*"                   : r"\breorganiz\w*",
    "Replac*"                      : r"\breplac\w*",
    "Restructur*"                  : r"\brestructur\w*",
    "Rework*"                      : r"\brework\w*",
    "Rewrit*"                      : r"\brewrit\w*",
    "Simplif*"                     : r"\bsimplif\w*",
    "Split*"                       : r"\bsplit\w*",
}

combined_pattern = '|'.join(KEYWORD_PATTERNS.values())
print(f"Pattern combiné ({len(KEYWORD_PATTERNS)} mots-clés)")

# %%
# TODO : Appliquez le pattern sur le body des commentaires
#
# INDICES :
#   1. Identifiez la bonne colonne body : [c for c in df_comments.columns if 'body' in c.lower()]
#   2. Créez une colonne booléenne 'is_refactoring' avec .str.contains()
#   3. Affichez le nombre et pourcentage de commentaires de refactoring

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.4 — Calculer la prévalence par agent
#
# > **Indice :** Utilisez `.groupby('agent').agg()` pour compter le total et la somme des `is_refactoring`, puis calculez le pourcentage.

# %%
# TODO : Tableau récapitulatif de prévalence par agent
#
# INDICE :
#   prevalence = df_comments.groupby('agent').agg(
#       total_comments=('is_refactoring', 'count'),
#       refactoring_comments=('is_refactoring', 'sum'),
#   )
#   prevalence['percentage'] = ...

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.5 — Taxonomie et distribution par catégorie
#
# Classifiez chaque commentaire de refactoring dans l'une des 6 catégories.
#
# > **Indice :** Créez un dictionnaire `CATEGORIES` qui associe chaque catégorie à une liste de regex. Écrivez une fonction `classify_refactoring(text)` qui retourne la première catégorie correspondante, ou `'Autre'` si aucune ne correspond. Appliquez-la avec `.apply()`.
# >
# > Catégories suggérées : Changements structurels, Nommage/lisibilité, Code mort/nettoyage, Organisation du code, Duplication, Remplacement/migration.

# %%
# TODO : Définissez les catégories et leurs patterns
#
# INDICE :
#   CATEGORIES = {
#       'Changements structurels': [r'\bextract\b', r'\binline\b', r'\bsplit\b', ...],
#       'Nommage / lisibilité':    [r'\brename', r'\bclarity', ...],
#       ...
#   }
#
#   def classify_refactoring(text):
#       # Itérez sur CATEGORIES, retournez la première catégorie matchée
#       ...
#
#   df_refactoring = df_comments[df_comments['is_refactoring']].copy()
#   df_refactoring['category'] = df_refactoring[body_col].apply(classify_refactoring)

# VOTRE CODE ICI

# %%
# TODO : Diagramme en barres — distribution par catégorie
#
# INDICE : df_refactoring['category'].value_counts().plot(kind='barh')

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.6 — Analyse par agent et par langage
#
# > **Indice :** Joignez `df_refactoring` avec `df_repos` pour récupérer la colonne `language`. Utilisez `pd.crosstab()` pour un tableau croisé agent × langage. Visualisez avec un barplot empilé.

# %%
# TODO : Analyse par agent et par langage
#
# INDICES :
#   1. Joignez df_refactoring avec df_repos sur repo_id
#   2. pd.crosstab(df_refactoring_lang['agent'], df_refactoring_lang['language'])
#   3. Visualisez les 8 langages les plus fréquents avec .plot(kind='bar', stacked=True)

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 1.7 — Validation manuelle (précision / rappel)
#
# Les commentaires à annoter vous seront envoyés sur Discord.
#
# > **Indice :**
# > 1. Exportez en CSV votre annotation manuelle
# > 2. Après annotation, calculez : `precision = TP / (TP + FP)` et `recall = TP / (TP + FN)`

# %%
# TODO : Échantillonnage et validation manuelle
#
# INDICES :
#   sample_positive = df_comments[df_comments['is_refactoring']].sample(50, random_state=42)
#   sample_negative = df_comments[~df_comments['is_refactoring']].sample(50, random_state=42)
#   sample_positive[[body_col]].to_csv('validation_positive.csv', index=False)
#
#   Après annotation :
#   TP = ...  # vrais positifs
#   FP = ...  # faux positifs
#   FN = ...  # faux négatifs
#   precision = TP / (TP + FP)
#   recall    = TP / (TP + FN)

# VOTRE CODE ICI

# %% [markdown]
# ---
# ## Partie 2 : Application des suggestions avec RefactoringMiner (12 pts + 2 bonus)
#
# > **Prérequis :** RefactoringMiner doit être installé et configuré (voir l'énoncé).
# > Cette partie se concentre sur les projets **Java** et **Python** (supportés par RefactoringMiner 3.0).

# %% [markdown]
# ### Étape 2.1 — Filtrer les projets Java et Python
#
# > **Indice :** Filtrez `df_repos` par langage, puis joignez avec `df_agentic` pour obtenir les PRs agentiques dans ces langages.

# %%
# ─── Chargement des outputs (étapes 1.1, 1.2, 2.1 déjà faites) ───
import pandas as pd
import os

OUTPUTS_DIR = "outputs"  # adapte si ton dossier est ailleurs

df_agentic = pd.read_parquet(os.path.join(OUTPUTS_DIR, "df_agentic.parquet"))
df_comments_agentic = pd.read_parquet(os.path.join(OUTPUTS_DIR, "df_comments_agentic.parquet"))
df_prs_java_python = pd.read_parquet(os.path.join(OUTPUTS_DIR, "df_prs_java_python.parquet"))

print(f"✅ df_agentic         : {len(df_agentic):,} PRs agentiques")
print(f"✅ df_comments_agentic: {len(df_comments_agentic):,} commentaires")
print(f"✅ df_prs_java_python : {len(df_prs_java_python):,} PRs Java/Python")
# Out:
# ✅ df_agentic         : 33,596 PRs agentiques
# ✅ df_comments_agentic: 26,868 commentaires
# ✅ df_prs_java_python : 8,469 PRs Java/Python

# %%
# Étape 2.1 — déjà réalisée (tp4_guide_steps.py)
# On charge directement le résultat depuis le parquet

# Tableau croisé language × agent (question 2.1.a)
crosstab_21 = pd.crosstab(
    df_prs_java_python['language'],
    df_prs_java_python['agent']
)
print("PRs agentiques Java/Python par agent :")
print(crosstab_21)
print(f"\nTotal : {len(df_prs_java_python):,} PRs")
# Out:
# PRs agentiques Java/Python par agent :
# agent     Claude_Code  Copilot  Cursor  Devin  OpenAI_Codex
# language
# Java               16      216      24      4          1018
# Python            100      559     254   1069          5209
#
# Total : 8,469 PRs

# %% [markdown]
# ### Étape 2.2 — Sélectionner les PRs avec commentaires de refactoring
#
# > **Indice :** Récupérez les `pr_id` uniques de `df_refactoring`, puis filtrez `df_prs_jp` pour ne garder que les PRs qui ont au moins un commentaire de refactoring.

# %%
import re

# Patterns de détection de refactoring (identiques à la cellule 1.3)
KEYWORD_PATTERNS_22 = {
    "Add*"                         : r"\badd\w*",
    "Chang*"                       : r"\bchang\w*",
    "Chang* the name"              : r"\bchang\w*\s+the\s+name",
    "Cleanup"                      : r"\bcleanup\b",
    "Clean* up"                    : r"\bclean\w*\s+up",
    "Code clarity"                 : r"\bcode\s+clarity",
    "Code clean*"                  : r"\bcode\s+clean\w*",
    "Code organization"            : r"\bcode\s+organization",
    "Code review"                  : r"\bcode\s+review",
    "Clean code"                   : r"\bclean\s+code",
    "Creat*"                       : r"\bcreat\w*",
    "Customiz*"                    : r"\bcustomiz\w*",
    "Easier to maintain"           : r"\beasier\s+to\s+maintain",
    "Encapsulat*"                  : r"\bencapsulat\w*",
    "Enhanc*"                      : r"\benhanc\w*",
    "Extend*"                      : r"\bextend\w*",
    "Extract*"                     : r"\bextract\w*",
    "Fix*"                         : r"\bfix\w*",
    "Inlin*"                       : r"\binlin\w*",
    "Improv*"                      : r"\bimprov\w*",
    "Improv* code quality"         : r"\bimprov\w*\s+code\s+quality",
    "Introduc*"                    : r"\bintroduc\w*",
    "Merg*"                        : r"\bmerg\w*",
    "Modif*"                       : r"\bmodif\w*",
    "Modulariz*"                   : r"\bmodulariz\w*",
    "Migrat*"                      : r"\bmigrat\w*",
    "Mov*"                         : r"\bmov\w*",
    "Organiz*"                     : r"\borganiz\w*",
    "Polish*"                      : r"\bpolish\w*",
    "Reduc*"                       : r"\breduc\w*",
    "Refactor*"                    : r"\brefactor\w*",
    "Refin*"                       : r"\brefin\w*",
    "Remov*"                       : r"\bremov\w*",
    "Remov* redundant code"        : r"\bremov\w*\s+redundant\s+code",
    "Renam*"                       : r"\brenam\w*",
    "Remov* unused dependencies"   : r"\bremov\w*\s+unused\s+dependenc\w*",
    "Reorganiz*"                   : r"\breorganiz\w*",
    "Replac*"                      : r"\breplac\w*",
    "Restructur*"                  : r"\brestructur\w*",
    "Rework*"                      : r"\brework\w*",
    "Rewrit*"                      : r"\brewrit\w*",
    "Simplif*"                     : r"\bsimplif\w*",
    "Split*"                       : r"\bsplit\w*",
}

def has_refactoring_keyword(text):
    if not isinstance(text, str):
        return False
    text_lower = text.lower()
    return any(re.search(pattern, text_lower) for pattern in KEYWORD_PATTERNS_22.values())

# Appliquer le filtre sur les commentaires
df_comments_agentic['is_refactoring'] = df_comments_agentic['body_comment'].apply(has_refactoring_keyword)

# PRs Java/Python avec au moins 1 commentaire de refactoring
pr_ids_with_refactoring = set(
    df_comments_agentic[df_comments_agentic['is_refactoring']]['pr_id'].unique()
)

df_prs_refactoring = df_prs_java_python[
    df_prs_java_python['id_pr'].isin(pr_ids_with_refactoring)
].copy()

print(f"PRs Java/Python avec ≥1 commentaire refactoring : {len(df_prs_refactoring):,}")
print()
print("Tableau croisé langage × agent :")
print(pd.crosstab(df_prs_refactoring['language'], df_prs_refactoring['agent']))
# Out:
# PRs Java/Python avec ≥1 commentaire refactoring : 684
#
# Tableau croisé langage × agent :
# agent     Claude_Code  Copilot  Cursor  Devin  OpenAI_Codex
# language
# Java                4       77       7      0            14
# Python             19      187      36    142           198

# %% [markdown]
# ### Étape 2.3 — Construire la chronologie par PR
#
# Pour chaque PR, identifiez les **commits de suivi** : commits effectués **après** un commentaire de refactoring.
#
# ```
# Temps ──────────────────────────────────────────────>
#
#   commit_1     comment_refactoring     commit_2 (suivi)     commit_3 (suivi)
#      │                 │                    │                     │
#      ▼                 ▼                    ▼                     ▼
#   ─────────────────────────────────────────────────────────────────
# ```
#
# > **Indices :**
# > - La table `pr_timeline` contient les événements : `event='committed'` pour les commits, avec `commit_id` = SHA et `created_at` = timestamp
# > - Certains événements `committed` n'ont pas de `created_at` → utilisez `.bfill()` pour propager le timestamp du prochain événement
# > - Comparez les timestamps des commentaires de refactoring avec ceux des commits pour identifier les commits de suivi

# %%
# Étape 2.3 — Charger et préparer la timeline

TIMELINE_CACHE = os.path.join(OUTPUTS_DIR, "df_timeline.parquet")

if os.path.exists(TIMELINE_CACHE):
    print("Chargement local de pr_timeline...")
    df_timeline = pd.read_parquet(TIMELINE_CACHE)
else:
    print("Téléchargement de pr_timeline depuis Hugging Face (~1 min)...")
    df_timeline = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_timeline.parquet")
    df_timeline.to_parquet(TIMELINE_CACHE, index=False)
    print(f"✅ Sauvegardé localement : {TIMELINE_CACHE}")

print(f"✅ pr_timeline : {len(df_timeline):,} événements")
print(f"   Colonnes : {list(df_timeline.columns)}")

# Convertir created_at sur TOUTE la timeline (avant de filtrer)
df_timeline['created_at'] = pd.to_datetime(df_timeline['created_at'], utc=True, errors='coerce')

# bfill sur TOUTE la timeline groupée par pr_id
# (les événements non-committed ont des timestamps qui remplissent les NaT des committed)
df_timeline['created_at'] = df_timeline.groupby('pr_id')['created_at'].transform(
    lambda x: x.ffill().bfill()
)

# Maintenant filtrer sur committed
df_tl_commits = df_timeline[df_timeline['event'] == 'committed'].copy()

non_nat = df_tl_commits['created_at'].notna().sum()
print(f"\nÉvénements committed : {len(df_tl_commits):,}")
print(f"Avec timestamp valide : {non_nat:,} ({100*non_nat/len(df_tl_commits):.1f}%)")
print(df_tl_commits[['pr_id', 'event', 'commit_id', 'created_at']].head(5))
# Out:
# Chargement local de pr_timeline...
# ✅ pr_timeline : 325,500 événements
#    Colonnes : ['pr_id', 'event', 'commit_id', 'created_at', 'actor', 'assignee', 'label', 'message']
#
# Événements committed : 79,735
# Avec timestamp valide : 77,148 (96.8%)
#         pr_id      event                                 commit_id  \
# 1  3205734508  committed  15a543882cbad0c9348640cffdd71fb71ac34953
# 6  3107321792  committed  cdd9bab35891037692f1d201db37d34d48342332
# 7  3107321792  committed  219323e2aa1dacd76a422ad24cabf6976c9a6ac0
# 8  3107321792  committed  58c52841e96e9fdcb70befadf7b3994519834861
# 9  3107321792  committed  b04470fe6bae5e6802f1fe83e7c5f0b9273e74a3
#
#                  created_at
# 1 2025-07-05 23:24:33+00:00
# 6 2025-06-01 14:15:35+00:00
# 7 2025-06-01 14:15:35+00:00
# 8 2025-06-01 14:15:35+00:00
# 9 2025-06-01 14:15:35+00:00

# %%
# Étape 2.3 — Calcul des commits de suivi (approche vectorisée)

# 1. Filtrer les commentaires de refactoring pour les 684 PRs seulement
pr_ids_684 = set(df_prs_refactoring['id_pr'].tolist())

df_ref = df_comments_agentic[
    df_comments_agentic['is_refactoring'] &
    df_comments_agentic['pr_id'].isin(pr_ids_684)
].copy()
df_ref['submitted_at'] = pd.to_datetime(df_ref['submitted_at'], utc=True, errors='coerce')
df_ref = df_ref.dropna(subset=['submitted_at'])
print(f"Commentaires de refactoring dans les 684 PRs : {len(df_ref):,}")

# Identifier les bonnes colonnes
id_col   = next((c for c in df_ref.columns if c in ['id_comment', 'id']), None)
path_col = next((c for c in df_ref.columns if 'path' in c.lower()), None)
print(f"  Colonne id commentaire : {id_col}")
print(f"  Colonne path           : {path_col}")

# 2. Commits de la timeline pour les 684 PRs seulement
df_tl_684 = df_tl_commits[df_tl_commits['pr_id'].isin(pr_ids_684)].copy()
print(f"Commits timeline pour les 684 PRs : {len(df_tl_684):,}")

# 3. Jointure comments × commits sur pr_id
df_cross = df_ref[['pr_id', id_col, path_col, 'submitted_at']].merge(
    df_tl_684[['pr_id', 'commit_id', 'created_at']],
    on='pr_id',
    how='left'
)

# 4. Garder seulement les commits APRÈS le commentaire
df_cross = df_cross[
    df_cross['created_at'].notna() &
    (df_cross['created_at'] > df_cross['submitted_at'])
]

# 5. Agréger par commentaire
df_followups = (
    df_cross
    .groupby(['pr_id', id_col, path_col])
    .agg(followup_shas=('commit_id', lambda x: list(x.dropna().unique())),
         n_followups=('commit_id', 'nunique'))
    .reset_index()
    .rename(columns={id_col: 'comment_id', path_col: 'comment_path'})
)

print(f"\n✅ Résultats :")
print(f"   Commentaires avec commits de suivi : {len(df_followups):,}")
if not df_followups.empty:
    print(f"   Moyenne commits de suivi : {df_followups['n_followups'].mean():.2f}")
    print(df_followups[['pr_id', 'comment_path', 'n_followups']].head(10))
# Out:
# Commentaires de refactoring dans les 684 PRs : 2,766
#   Colonne id commentaire : id_comment
#   Colonne path           : path
# Commits timeline pour les 684 PRs : 3,338
#
# ✅ Résultats :
#    Commentaires avec commits de suivi : 1,035
#    Moyenne commits de suivi : 3.26
#         pr_id  \
# 0  2756921963
# 1  2771417743
# 2  2771417743
# 3  2771599553
# 4  2771599553
# 5  2773964481
# 6  2773964481
# 7  2773964481
# 8  2773964481
# 9  2776603613
#
#                                                                            comment_path  \
# 0                                    tests/litellm_handlers/test_litellm_integration.py
# 1                                         vlmrun/hub/schemas/document/bank_statement.py
# 2                                         vlmrun/hub/schemas/document/bank_statement.py
# 3  src/bespokelabs/curator/request_processor/batch/anthropic_batch_request_processor.py
# 4  src/bespokelabs/curator/request_processor/batch/anthropic_batch_request_processor.py
# 5                                                    src/bespokelabs/curator/llm/llm.py
# 6                                                    src/bespokelabs/curator/llm/llm.py
# 7                                                    src/bespokelabs/curator/llm/llm.py
# 8                                                    src/bespokelabs/curator/llm/llm.py
# 9                                           vlmrun/hub/schemas/contrib/media/tv-news.py
#
#    n_followups
# 0            6
# 1            5
# 2            5
# 3            1
# 4            1
# 5           15
# 6           15
# 7            7
# 8            7
# 9            1

# %% [markdown]
# ### Étape 2.4 — Exécuter RefactoringMiner
#
# > **Indices :**
# > - Le chemin vers l'exécutable dépend de votre installation. Vérifiez avec `!ls /chemin/vers/RefactoringMiner`
# > - Mode `-gc` : analyse un commit distant (nécessite token GitHub)
# > - Mode `-gp` : analyse une PR entière (tous les commits)
# > - Commencez par tester avec un petit échantillon (`SAMPLE_SIZE = 5`)
# > - Sauvegardez les résultats intermédiaires en JSON pour éviter de tout relancer

# %%
# Étape 2.4 — Test de RefactoringMiner
# RMINER_CMD est défini dans la cellule 0.2

OUTPUT_RM_DIR = os.path.join("outputs", "rminer")
os.makedirs(OUTPUT_RM_DIR, exist_ok=True)

# Test avec le dépôt public officiel de l'auteur de RefactoringMiner
TEST_URL = "https://github.com/danilofes/refactoring-toy-example.git"
TEST_SHA = "36287f7c3b09eff78395267a3ac0d7da067863fd"
TEST_OUT = os.path.join(OUTPUT_RM_DIR, "test_output.json")

cmd = RMINER_CMD + ["-gc", TEST_URL, TEST_SHA, "60", "-json", TEST_OUT]
print("Commande :", " ".join(cmd))

result = subprocess.run(cmd, capture_output=True, text=True, timeout=120)
print("Return code:", result.returncode)

if os.path.exists(TEST_OUT):
    with open(TEST_OUT) as f:
        test_data = json.load(f)
    n = sum(len(c.get("refactorings", [])) for c in test_data.get("commits", []))
    print(f"✅ Test réussi — {n} refactoring(s) détecté(s) dans le commit de test")
else:
    print("❌ Fichier JSON non créé")
    print("stdout:", result.stdout[:400])
    print("stderr:", result.stderr[:400])
# Out:
# Commande : java -cp /Users/Nahel/RefactoringMiner/build/distributions/RefactoringMiner-3.1.3/lib/* org.refactoringminer.RefactoringMiner -gc https://github.com/danilofes/refactoring-toy-example.git 36287f7c3b09eff78395267a3ac0d7da067863fd 60 -json outputs/rminer/test_output.json
# Return code: 0
# ✅ Test réussi — 0 refactoring(s) détecté(s) dans le commit de test

# %%
# Étape 2.4 — Fonctions run_refactoringminer_commit() et run_refactoringminer_pr()

def run_refactoringminer_commit(repo_full_name, sha, timeout=120):
    """Analyse un commit avec RefactoringMiner -gc. Retourne le dict JSON ou None."""
    out_file = os.path.join(OUTPUT_RM_DIR, f"commit_{sha[:12]}.json")
    if os.path.exists(out_file):
        with open(out_file) as f:
            return json.load(f)
    repo_url = f"https://github.com/{repo_full_name}.git"
    cmd = RMINER_CMD + ["-gc", repo_url, sha, str(timeout), "-json", out_file]
    try:
        subprocess.run(cmd, capture_output=True, text=True, timeout=timeout + 10)
        if os.path.exists(out_file):
            with open(out_file) as f:
                return json.load(f)
        return None
    except subprocess.TimeoutExpired:
        print(f"  ⏱ Timeout: {repo_full_name} @ {sha[:8]}")
        return None
    except Exception as e:
        print(f"  ❌ Erreur: {e}")
        return None


def run_refactoringminer_pr(repo_full_name, pr_number, timeout=300):
    """Analyse une PR entière avec RefactoringMiner -gp. Retourne le dict JSON ou None."""
    safe_name = repo_full_name.replace("/", "_")
    out_file = os.path.join(OUTPUT_RM_DIR, f"pr_{safe_name}_{pr_number}.json")
    if os.path.exists(out_file):
        with open(out_file) as f:
            return json.load(f)
    repo_url = f"https://github.com/{repo_full_name}.git"
    cmd = RMINER_CMD + ["-gp", repo_url, str(pr_number), str(timeout), "-json", out_file]
    try:
        subprocess.run(cmd, capture_output=True, text=True, timeout=timeout + 30)
        if os.path.exists(out_file):
            with open(out_file) as f:
                return json.load(f)
        return None
    except subprocess.TimeoutExpired:
        print(f"  ⏱ Timeout: {repo_full_name} PR#{pr_number}")
        return None
    except Exception as e:
        print(f"  ❌ Erreur: {e}")
        return None


print("✅ Fonctions run_refactoringminer_commit() et run_refactoringminer_pr() définies")
# Out:
# ✅ Fonctions run_refactoringminer_commit() et run_refactoringminer_pr() définies

# %%
# Étape 2.4 — Boucle d'analyse RefactoringMiner (parallèle)
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed

SAMPLE_SIZE = 684   # augmentez après validation (ex: 50, puis 684)
MAX_WORKERS = 8   # workers parallèles (GitHub API)
CHECKPOINT_FILE = os.path.join(OUTPUT_RM_DIR, "rminer_results.json")

# Charger checkpoint si disponible
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE) as f:
        rminer_results = json.load(f)
    print(f"[checkpoint] {len(rminer_results)} PRs déjà analysées")
else:
    rminer_results = {}

pr_number_col = 'number'
repo_name_col = 'full_name'

sample_prs = df_prs_refactoring.head(SAMPLE_SIZE)
print(f"\nAnalyse de {SAMPLE_SIZE} PRs avec RefactoringMiner (-gp) — {MAX_WORKERS} workers...")

lock = threading.Lock()

def analyse_pr(pr_row):
    pr_id = str(pr_row['id_pr'])
    with lock:
        if pr_id in rminer_results:
            return pr_id, None
    pr_num = int(pr_row[pr_number_col])
    repo   = str(pr_row[repo_name_col])
    print(f"  → {repo} PR#{pr_num}")
    result = run_refactoringminer_pr(repo, pr_num, timeout=300)
    return pr_id, result

rows = [row for _, row in sample_prs.iterrows()]

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(analyse_pr, row): row for row in rows}
    for i, future in enumerate(tqdm(as_completed(futures), total=len(rows), desc="PRs"), 1):
        pr_id, result = future.result()
        if result is not None:
            with lock:
                rminer_results[pr_id] = result
        if i % 5 == 0:
            with lock:
                with open(CHECKPOINT_FILE, 'w') as f:
                    json.dump(rminer_results, f)

with open(CHECKPOINT_FILE, 'w') as f:
    json.dump(rminer_results, f)

analyzed = sum(1 for v in rminer_results.values() if v is not None)
print(f"\n✅ {analyzed}/{len(sample_prs)} PRs analysées")
for pr_id, res in list(rminer_results.items())[:3]:
    if res:
        n_ref = sum(len(c.get('refactorings', [])) for c in res.get('commits', []))
        print(f"  PR {pr_id}: {n_ref} refactoring(s) détecté(s)")
# Out:
# [checkpoint] 0 PRs déjà analysées
#
# Analyse de 684 PRs avec RefactoringMiner (-gp) — 8 workers...
#   → dotCMS/core PR#32656
#   → mlflow/mlflow PR#16658
#   → pytorch/pytorch PR#157910
#   → dotCMS/core PR#32609
#   → Deep-Learning-Profiling-Tools/triton-viz PR#86
#   → zenml-io/zenml PR#3375
#   → haasonsaas/ocode PR#7
#   → TracecatHQ/tracecat PR#1287
# PRs:   0%|          | 0/684 [00:00<?, ?it/s]
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/kura PR#53
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → pathintegral-institute/mcpm.sh PR#221
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1729
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MervinPraison/PraisonAI PR#1021
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → BeehiveInnovations/zen-mcp-server PR#83
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16482
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16758
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MaiM-with-u/MaiBot PR#195
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → dotCMS/core PR#32771
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → robusta-dev/holmesgpt PR#695
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → pab1it0/prometheus-mcp-server PR#39
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → dotCMS/core PR#32561
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PrefectHQ/prefect PR#18363
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16442
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vllm-project/vllm PR#19396
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6752
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → hacs/integration PR#4694
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/mssql-python PR#156
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16913
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16009
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16014
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7918
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7783
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7431
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3888
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7739
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4601
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16385
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#34153
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41465
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4262
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → openmc-dev/openmc PR#3471
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41228
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3811
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#500
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16533
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#501
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15996
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → nearai/nearai PR#1179
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7661
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/mssql-python PR#149
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2426
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7779
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7439
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#315
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/debug-gym PR#126
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7391
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15936
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41422
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → a16z/halmos PR#533
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Olive PR#1897
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#521
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → port-labs/ocean PR#1780
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure-Samples/aisearch-openai-rag-audio PR#104
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4589
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Qcodes PR#7240
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#512
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4559
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16112
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#524
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4252
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4255
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4257
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7801
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15987
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15989
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15991
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4407
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7942
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/debug-gym PR#161
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45795
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15953
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35602
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15865
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7481
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → EduMIPS64/edumips64 PR#1360
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Olive PR#1915
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2388
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2392
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7602
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15909
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7535
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3843
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#537
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41852
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2447
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → hyperxpro/Brotli4j PR#218
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41663
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7129
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → etna-team/etna PR#676
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2437
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Olive PR#1907
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4631
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4287
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4288
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4289
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mixpanel/mixpanel-android PR#866
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7729
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3808
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16367
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2382
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2383
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 1c-syntax/bsl-language-server PR#3486
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4608
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4610
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41491
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2050
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3863
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15856
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41734
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45808
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41413
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#347
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4269
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#34932
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41352
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15848
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#342
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 1c-syntax/bsl-language-server PR#3481
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → EduMIPS64/edumips64 PR#1361
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7771
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/mcp-for-beginners PR#56
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2077
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3824
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#34576
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/python-docs-zh-tw PR#1117
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → wgzhao/Addax PR#1321
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7553
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4551
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3898
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4607
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41480
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2036
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4260
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16546
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4262
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15889
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#541
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/torchgeo PR#2861
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → TorchIO-project/torchio PR#1330
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16140
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16141
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → github/issue-metrics PR#540
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → a16z/halmos PR#544
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16018
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7760
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41463
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → yutto-dev/yutto PR#539
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41866
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35372
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35374
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15926
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15929
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7122
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → jeroenterheerdt/HAsmartirrigation PR#585
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#515
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → zfit/zfit PR#644
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35209
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3839
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#536
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16221
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3855
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45595
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16080
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2401
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4561
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15828
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35347
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6565
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2019
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spack/spack PR#50977
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7984
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6697
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → stefankoegl/python-json-pointer PR#67
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15934
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16551
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#498
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#34581
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7055
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7056
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3872
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2404
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7058
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45797
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45800
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45801
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16088
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15978
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → facioquo/stock-indicators-python PR#434
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/python-docs-zh-tw PR#1114
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → opsmill/infrahub PR#6753
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7644
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16273
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#519
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2406
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7063
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → a16z/halmos PR#551
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → port-labs/ocean PR#1770
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → port-labs/ocean PR#1774
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Qcodes PR#7222
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mosecorg/mosec PR#658
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mixpanel/mixpanel-android PR#862
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7124
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/magentic-ui PR#252
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3816
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3818
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#363
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4599
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41693
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4353
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/python-docs-zh-tw PR#1102
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/python-docs-zh-tw PR#1105
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16311
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2041
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7619
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16231
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/lisa PR#3822
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7749
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7755
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6747
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → weecology/DeepForest PR#1089
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#528
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vaadin/flow PR#21820
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#8029
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onnx/onnx PR#7112
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → a16z/halmos PR#541
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6799
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7397
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/autogen PR#6563
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35632
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → espressif/esptool PR#1103
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → apolloconfig/apollo PR#5419
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → port-labs/ocean PR#1750
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Olive PR#1996
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15839
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16878
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#8008
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35422
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#386
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4328
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/onnxscript PR#2455
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-java PR#45590
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7423
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7425
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7426
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → econ-ark/HARK PR#1580
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → econ-ark/HARK PR#1581
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#514
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16307
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spcl/dace PR#2043
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4591
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#535
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/AzureTRE PR#4602
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → frenck/spook PR#975
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#15893
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → a16z/halmos PR#539
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/typespec PR#7967
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16526
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → opsmill/infrahub PR#6767
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35007
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41942
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → EduMIPS64/edumips64 PR#1364
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16927
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/python-docs-zh-tw PR#1110
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → NewFuture/DDNS PR#505
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → numba/numba PR#10133
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/fabric-cicd PR#369
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/Qcodes PR#7213
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#41620
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4377
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4388
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → valkey-io/valkey-glide PR#4390
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → camunda/camunda PR#35888
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16541
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16543
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → microsoft/ApplicationInsights-Java PR#4310
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Azure/azure-sdk-for-python PR#42024
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → nandyalu/trailarr PR#259
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mlflow/mlflow PR#16243
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → commaai/opendbc PR#2269
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → TobikoData/sqlmesh PR#4712
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#344
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#9961
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#9962
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → stanford-crfm/levanter PR#1091
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2441
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1727
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → janbjorge/pgqueuer PR#441
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → browser-use/browser-use PR#2166
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onyx-dot-app/onyx PR#4823
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python/devguide PR#1583
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → phospho-app/phosphobot PR#125
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#303
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#487
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#489
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#490
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#492
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#498
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → TobikoData/sqlmesh PR#4667
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → oraios/serena PR#169
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → basetenlabs/truss PR#1679
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1428
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1430
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AIAdvantage/chatgpt-api-youtube PR#14
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1669
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Uberi/speech_recognition PR#845
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#355
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → andrewm4894/anomstack PR#177
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#499
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#502
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#503
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#354
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#358
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → langflow-ai/langflow PR#9062
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vllm-project/vllm PR#19145
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#461
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → sakaiproject/sakai PR#13754
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#318
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Stirling-Tools/Stirling-PDF PR#3990
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → dropseed/plain PR#37
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#380
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#382
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#385
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#386
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#393
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#394
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#396
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#411
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#413
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#420
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#423
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#424
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1622
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#350
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OEvortex/Webscout PR#52
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → operaton/operaton PR#904
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#372
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#305
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#306
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Stirling-Tools/Stirling-PDF PR#3622
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#410
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2930
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#9958
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → superlinear-ai/raglite PR#137
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OEvortex/Webscout PR#68
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1664
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#377
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1426
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vllm-project/vllm PR#21135
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → lordmauve/pgzero PR#366
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → andrewm4894/anomstack PR#167
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1666
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#361
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#363
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#364
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#368
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#369
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#370
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#374
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#378
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#432
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#433
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#438
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#440
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#441
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#443
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#444
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#371
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#449
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#452
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#457
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#460
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#461
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → VerisimilitudeX/DNAnalyzer PR#529
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#307
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#314
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#315
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#317
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#322
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#325
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#326
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#327
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#334
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#339
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#340
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#376
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → zenml-io/zenml PR#3680
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → wandb/wandbot PR#99
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#353
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → unclecode/crawl4ai PR#1137
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → netket/netket PR#2054
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bruin-data/ingestr PR#256
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1407
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#10032
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#386
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → oraios/serena PR#171
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MervinPraison/PraisonAI PR#596
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → TobikoData/sqlmesh PR#4713
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → pytorch/pytorch PR#155658
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Stirling-Tools/Stirling-PDF PR#3993
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → apache/pinot PR#16078
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vllm-project/vllm PR#21146
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#308
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Stirling-Tools/Stirling-PDF PR#3992
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → hivesolutions/netius PR#44
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Project-MONAI/model-zoo PR#754
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#484
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#486
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OEvortex/Webscout PR#64
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → jlowin/fastmcp PR#492
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2475
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2476
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#352
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#3063
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#465
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1372
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#466
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#397
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1697
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → roboflow/inference PR#1350
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1619
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#9965
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1737
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Kiln-AI/Kiln PR#365
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → VerisimilitudeX/DNAnalyzer PR#544
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PriorLabs/TabPFN PR#342
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → operaton/operaton PR#913
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → DogukanUrker/FlaskBlog PR#191
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#371
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#9960
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1452
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#482
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#10153
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#10063
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#468
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1410
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1386
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1623
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → stanfordnlp/dspy PR#8478
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1703
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → DogukanUrker/FlaskBlog PR#189
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → cartography-cncf/cartography PR#1624
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → sunbeam-labs/sunbeam PR#540
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#459
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → pytorch/pytorch PR#155615
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OEvortex/Webscout PR#56
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → hivesolutions/netius PR#45
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → janbjorge/pgqueuer PR#415
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → VerisimilitudeX/DNAnalyzer PR#543
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#465
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#467
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#475
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#476
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#477
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#505
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → astronomer/airflow-ai-sdk PR#31
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Nativu5/Gemini-FastAPI PR#5
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → csvoss/onelinerizer PR#87
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → apache/pinot PR#16085
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MervinPraison/PraisonAI PR#628
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → spring-projects/spring-kafka PR#3944
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → roboflow/inference PR#1319
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2729
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → andrewm4894/anomstack PR#175
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → stanfordnlp/dspy PR#8238
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PrunaAI/pruna PR#144
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → DogukanUrker/FlaskBlog PR#197
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → netket/netket PR#2064
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Nativu5/Gemini-FastAPI PR#7
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → operaton/operaton PR#1001
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1660
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2399
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OEvortex/Webscout PR#57
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#417
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#345
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#346
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#347
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#350
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#351
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#353
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#354
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#355
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#357
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MontrealAI/AGI-Alpha-Agent-v0 PR#360
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → python-cachier/cachier PR#294
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → zenml-io/zenml PR#3678
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Significant-Gravitas/AutoGPT PR#10016
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → johnpaulett/python-hl7 PR#67
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1395
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → julep-ai/julep PR#1398
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Skyvern-AI/skyvern PR#2435
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → iterative/datachain PR#1215
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#525
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#488
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#489
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#504
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#512
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → iterative/datachain PR#1227
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → OpenPipe/ART PR#167
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → StarRocks/starrocks PR#61394
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#93189
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#94889
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → StarRocks/starrocks PR#61403
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1644
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1645
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → zenml-io/zenml PR#3744
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → sakaiproject/sakai PR#13874
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → teaxyz/chai PR#133
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#94573
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → allenai/open-instruct PR#779
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#95329
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → StarRocks/starrocks PR#61224
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PostHog/posthog PR#35081
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#93224
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → browser-use/browser-use PR#2532
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#94169
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → pixeltable/pixeltable PR#729
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#465
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → MaiM-with-u/MaiBot PR#1045
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#476
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → browser-use/browser-use PR#2129
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → kyegomez/swarms PR#951
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → datahub-project/datahub PR#14258
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#95780
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → StarRocks/starrocks PR#61244
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → teaxyz/chai PR#112
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Bandit-HaxUnit/haxunit PR#35
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry PR#93402
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → iterative/datachain PR#1191
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → StarRocks/starrocks PR#61248
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → aipotheosis-labs/aci PR#520
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → WorkflowAI/WorkflowAI PR#453
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → getsentry/sentry-python PR#4474
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → EvolvingLMMs-Lab/lmms-eval PR#734
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → appdotbuild/agent PR#168
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → onyx-dot-app/onyx PR#3925
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60252
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#56355
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#56356
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#72
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → patched-codes/patchwork PR#1192
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55783
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#320
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52634
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52636
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ag2ai/build-with-ag2 PR#16
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52659
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52663
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52664
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#53606
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#632
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1447
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#58
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#60
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1446
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60225
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → appdotbuild/agent PR#299
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#122
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#123
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#124
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1518
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AgentOps-AI/agentops PR#650
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1747
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → elementary-data/dbt-data-reliability PR#831
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1550
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1478
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → mongodb/specifications PR#1800
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#121
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62864
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1474
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#3126
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63320
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63321
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63328
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1328
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1331
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#719
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#721
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#59764
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bentoml/BentoML PR#5231
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → modal-labs/modal-client PR#2781
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1305
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1435
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1549
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#52
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bespokelabsai/curator PR#305
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bespokelabsai/curator PR#308
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62497
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → elementary-data/dbt-data-reliability PR#832
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → elementary-data/dbt-data-reliability PR#833
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → whitphx/streamlit-webrtc PR#1930
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2870
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#672
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60329
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2552
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62436
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1454
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → PromtEngineer/localGPT PR#846
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2588
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2594
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bespokelabsai/curator PR#322
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bespokelabsai/curator PR#324
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#579
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#582
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#583
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex PR#5226
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62476
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55176
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#61644
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#341
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1313
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1314
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55780
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2537
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1543
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#677
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#679
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#53235
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#604
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1484
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex PR#5555
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62914
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62915
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62916
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62919
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62920
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62922
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62924
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62925
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62927
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1486
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1489
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1490
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#574
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → bentoml/BentoML PR#5176
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62108
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55244
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#691
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63290
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63291
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#3113
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#1937
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → appdotbuild/agent PR#75
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55709
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → langbot-app/LangBot PR#1393
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1480
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#61443
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → Flagsmith/flagsmith PR#5477
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60531
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#697
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#67
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62123
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#62133
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex-web PR#1453
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → ai-shifu/ai-shifu PR#592
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#44
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#615
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → marimo-team/marimo PR#3806
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60991
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52578
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#52590
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#55808
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#3060
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → crewAIInc/crewAI PR#2476
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → vlm-run/vlmrun-hub PR#74
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → reflex-dev/reflex PR#5616
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → 567-labs/instructor PR#1737
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AgentOps-AI/agentops PR#603
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#63360
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → elementary-data/dbt-data-reliability PR#830
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AgentOps-AI/agentops PR#728
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AgentOps-AI/agentops PR#729
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/airbyte PR#60883
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → AgentOps-AI/agentops PR#707
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → appdotbuild/agent PR#292
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   → airbytehq/PyAirbyte PR#695
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)  ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#   ❌ Erreur: Expecting value: line 3 column 1 (char 15)
#
# ✅ 0/684 PRs analysées

# %% [markdown]
# ### Étape 2.5 — Croiser les résultats et classifier
#
# Pour chaque commentaire de refactoring, vérifiez si un refactoring a été détecté dans un commit de suivi touchant le même fichier.
#
# > **Indice — Schéma de classification :**
# > ```
# > Pour chaque commentaire de refactoring :
# >   1. Y a-t-il des commits de suivi ?
# >      NON → "PR abandonnée" (si non fusionnée) ou "Non appliqué"
# >   2. RefactoringMiner détecte-t-il un refactoring dans le même fichier ?
# >      OUI → "Appliqué (confirmé)"
# >      NON → "Appliqué (non confirmé)" ou "Non appliqué"
# > ```
# >
# > Dans la sortie RefactoringMiner, les fichiers sont dans `leftSideLocations[0].filePath` et `rightSideLocations[0].filePath`.

# %%
# TODO : Écrire classify_application(comment_path, followup_commits, rminer_results, pr_merged)
#
# INDICES :
#   1. Si pas de followup_commits → 'PR abandonnée' ou 'Non appliqué'
#   2. Pour chaque SHA de suivi, cherchez les refactorings dans rminer_results
#   3. Comparez comment_path avec les filePath dans les refactorings détectés
#   4. Retournez la catégorie appropriée

# VOTRE CODE ICI

# %%
# TODO : Appliquer la classification sur tous les commentaires de refactoring
#
# INDICES :
#   1. Construisez un index {sha: [refactorings]} depuis rminer_results
#   2. Pour chaque PR analysée, appelez get_followup_commits()
#   3. Pour chaque commentaire, appelez classify_application()
#   4. Stockez dans une liste de dicts → DataFrame df_results
#   5. Affichez df_results['classification'].value_counts()

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 2.6 — Calculer les taux d'application
#
# > **Indice :** Utilisez `pd.crosstab()` pour un tableau agent × classification. Normalisez par ligne pour obtenir des pourcentages. Visualisez avec un barplot empilé.

# %%
# TODO : Diagramme en barres empilées par agent + comparaison Java vs Python
#
# INDICES :
#   ct = pd.crosstab(df_results['agent'], df_results['classification'])
#   ct_pct = ct.div(ct.sum(axis=1), axis=0) * 100
#   ct_pct.plot(kind='bar', stacked=True, colormap='Set2')

# VOTRE CODE ICI

# %% [markdown]
# ### Étape 2.7 (Bonus) — Correspondance sémantique
#
# Pour les cas « appliqué confirmé », vérifiez si le type de refactoring détecté correspond à la suggestion.
#
# > **Indice :** Créez un mapping entre les mots-clés de la suggestion et les types RefactoringMiner. Par exemple, le mot `'extract'` dans un commentaire devrait correspondre à `'Extract Method'`, `'Extract Class'`, etc. dans les résultats.

# %%
# TODO (Bonus) : Vérifier la correspondance sémantique
#
# INDICE :
#   SUGGESTION_TO_RMINER = {
#       'extract': ['Extract Method', 'Extract Class', ...],
#       'rename':  ['Rename Method', 'Rename Variable', ...],
#       'inline':  ['Inline Method', 'Inline Variable'],
#       ...
#   }
#
#   def check_semantic_match(comment_body, detected_type):
#       # Vérifiez si un mot-clé du commentaire correspond au type détecté
#       ...

# VOTRE CODE ICI

# %% [markdown]
# ---
# ## Annexe : Fonctions utilitaires
#
# Quelques fonctions utiles que vous pouvez réutiliser.

# %%
def safe_json_load(filepath):
    """Charge un fichier JSON en gérant les erreurs."""
    try:
        with open(filepath) as f:
            return json.load(f)
    except (json.JSONDecodeError, FileNotFoundError) as e:
        print(f"Erreur chargement {filepath}: {e}")
        return None


def extract_refactorings_from_rminer(result_json):
    """
    Extrait la liste plate de refactorings depuis la sortie RefactoringMiner.

    Returns:
        list of dict: [{sha, type, description, filePath}, ...]
    """
    refactorings = []
    if not result_json:
        return refactorings
    for commit in result_json.get('commits', []):
        sha = commit.get('sha1', '')
        for ref in commit.get('refactorings', []):
            left_files = [loc.get('filePath', '') for loc in ref.get('leftSideLocations', [])]
            right_files = [loc.get('filePath', '') for loc in ref.get('rightSideLocations', [])]
            refactorings.append({
                'sha': sha,
                'type': ref.get('type', ''),
                'description': ref.get('description', ''),
                'leftFiles': left_files,
                'rightFiles': right_files,
            })
    return refactorings

print("Fonctions utilitaires chargées.")
